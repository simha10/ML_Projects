# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#    beds  baths    size size_units  lot_size lot_size_units  zip_code  \
# 0     3    2.5  2590.0       sqft   6000.00           sqft     98144
# 1     4    2.0  2240.0       sqft      0.31           acre     98106
# 2     4    3.0  2040.0       sqft   3783.00           sqft     98107
# 3     4    3.0  3800.0       sqft   5175.00           sqft     98199
# 4     2    2.0  1042.0       sqft       NaN            NaN     98102
#
#        price
# 0   795000.0
# 1   915000.0
# 2   950000.0
# 3  1950000.0
# 4   950000.0

# %%
train_df.shape
# Out:
# (2016, 8)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   beds            2016 non-null   int64
#  1   baths           2016 non-null   float64
#  2   size            2016 non-null   float64
#  3   size_units      2016 non-null   object
#  4   lot_size        1669 non-null   float64
#  5   lot_size_units  1669 non-null   object
#  6   zip_code        2016 non-null   int64
#  7   price           2016 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 126.1+ KB

# %%
train_df.isna().sum()
# Out:
# beds                0
# baths               0
# size                0
# size_units          0
# lot_size          347
# lot_size_units    347
# zip_code            0
# price               0
# dtype: int64

# %%
train_df.columns
# Out:
# Index(['beds', 'baths', 'size', 'size_units', 'lot_size', 'lot_size_units',
#        'zip_code', 'price'],
#       dtype='object')

# %%
train_df.drop(columns=['size_units','lot_size','lot_size_units'], inplace=True)

# %%
train_df.describe()
# Out:
#               beds        baths          size      zip_code         price
# count  2016.000000  2016.000000   2016.000000   2016.000000  2.016000e+03
# mean      2.857639     2.159970   1735.740575  98123.638889  9.636252e+05
# std       1.255092     1.002023    920.132591     22.650819  9.440954e+05
# min       1.000000     0.500000    250.000000  98101.000000  1.590000e+05
# 25%       2.000000     1.500000   1068.750000  98108.000000  6.017500e+05
# 50%       3.000000     2.000000   1560.000000  98117.000000  8.000000e+05
# 75%       4.000000     2.500000   2222.500000  98126.000000  1.105250e+06
# max      15.000000     9.000000  11010.000000  98199.000000  2.500000e+07

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   beds      2016 non-null   int64
#  1   baths     2016 non-null   float64
#  2   size      2016 non-null   float64
#  3   zip_code  2016 non-null   int64
#  4   price     2016 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 78.9 KB

# %%
train_df['beds'].value_counts()
# Out:
# beds
# 3     645
# 2     560
# 4     398
# 1     256
# 5     123
# 6      22
# 9       5
# 7       3
# 8       2
# 15      1
# 14      1
# Name: count, dtype: int64

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#    beds  baths    size size_units  lot_size lot_size_units  zip_code  \
# 0     3    3.0  2850.0       sqft   4200.00           sqft     98119
# 1     4    5.0  3040.0       sqft   5002.00           sqft     98106
# 2     3    1.0  1290.0       sqft   6048.00           sqft     98125
# 3     3    2.0  2360.0       sqft      0.28           acre     98188
# 4     3    3.5  1942.0       sqft   1603.00           sqft     98107
#
#        price
# 0  1175000.0
# 1  1057500.0
# 2   799000.0
# 3   565000.0
# 4  1187000.0

# %%
test_df.drop(columns=['size_units','lot_size', 'lot_size_units'], inplace=True)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   beds      505 non-null    int64
#  1   baths     505 non-null    float64
#  2   size      505 non-null    float64
#  3   zip_code  505 non-null    int64
#  4   price     505 non-null    float64
# dtypes: float64(3), int64(2)
# memory usage: 19.9 KB

# %%
test_df.head()
# Out:
#    beds  baths    size  zip_code      price
# 0     3    3.0  2850.0     98119  1175000.0
# 1     4    5.0  3040.0     98106  1057500.0
# 2     3    1.0  1290.0     98125   799000.0
# 3     3    2.0  2360.0     98188   565000.0
# 4     3    3.5  1942.0     98107  1187000.0

# %%
# Define the model
from sklearn.ensemble import RandomForestRegressor
RFModel = RandomForestRegressor(random_state=0)

# %%
# Split the training data into training and validation sets
from sklearn.model_selection import train_test_split
X = train_df.drop('price', axis=1)
y = train_df['price']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
RFModel.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = RFModel.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mae = mean_absolute_error(y_val, y_pred)
print(f'Mean Absolute Error (MAE) on validation set: {mae}')
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print(f'Root Mean Squared Error (RMSE) on validation set: {rmse}')
# Out:
# Mean Absolute Error (MAE) on validation set: 234664.1224339934
# Root Mean Squared Error (RMSE) on validation set: 511405.7922586817

# %%
test_predictions = RFModel.predict(test_df.drop('price', axis=1))

# %%
def predict_house_price(model):
  """
  Predicts the price of a house based on user-provided features.

  Args:
    model: The trained machine learning model to use for prediction.

  Returns:
    The predicted price of the house.
  """
  input_features = {}
  for column in test_df.columns:
    if column != 'price':
      value = input(f"Enter the value for '{column}': ")
      # Attempt to convert the input to a numeric type
      try:
        value = int(value)
      except ValueError:
        try:
          value = float(value)
        except ValueError:
          pass  # Keep the value as a string if it's not numeric
      input_features[column] = value

  # Create a DataFrame from the input features
  input_data = pd.DataFrame([input_features])

  # Make the prediction
  predicted_price = model.predict(input_data)[0]

  return predicted_price

# Example usage
predicted_price = predict_house_price(RFModel)
print(f"Predicted Price: ${predicted_price:,.2f}")
# Out:
# Enter the value for 'beds': 3
# Enter the value for 'baths': 4
# Enter the value for 'size': 3040
# Enter the value for 'zip_code': 98106
# Predicted Price: $1,986,090.00
